# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
# %matplotlib inline
# Out:
# In C:\Users\adars_000\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\adars_000\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\adars_000\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\adars_000\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')

# %%
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df2.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
df2.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#printing total records
df2.shape[0]
# Out:
# 4622

# %%
df2.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
df2.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#how is the data indexed?
df2.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
most_ordered = df2.groupby(by = 'item_name')
most_ordered = most_ordered.sum()
most_ordered.sort_values(['quantity'], ascending = False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
df2.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
most_orderedCD = df2.groupby('choice_description')
most_orderedCD = most_orderedCD.sum()
most_orderedCD.sort_values(['quantity'], ascending = False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
df2.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
# to convert item_price to dollar

dollar = lambda x: float(x[1:-1])
df2.item_price = df2.item_price.apply(dollar)

# %%
df2.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
leastordered = df2.groupby('item_name')
leastordered = leastordered.sum()
leastordered.head()
# Out:
#                        order_id  quantity  item_price
# item_name
# 6 Pack Soft Drink         52322        55      356.95
# Barbacoa Bowl             53972        66      672.36
# Barbacoa Burrito          74718        91      894.75
# Barbacoa Crispy Tacos      5613        12      120.21
# Barbacoa Salad Bowl        9708        10      106.40

# %%
total_price = (df2['quantity']*df2['item_price']).sum()
print("Total revenue is: $",str(np.round(total_price,2)))
# Out:
# Total revenue is: $ 39237.02

# %%
Np = pd.DataFrame(df2[["item_name","item_price"]])
Np
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
# delete the duplicates from dataframe Np

Noduplicates = df2.drop_duplicates(['item_name','item_price'])
Noduplicates
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4237      1691         2                    Chips and Guacamole
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
# 4509      1793         1                                  Chips
# 4510      1793         1                          Barbacoa Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# select only those products with quantity equals to 1
only1 = Noduplicates[Noduplicates.quantity == 1]
only1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 5         3         1                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98

# %%
Nodup = df2.drop_duplicates(['item_price','item_price'])
Nodup
# Out:
#       order_id  quantity                     item_name  \
# 0            1         1  Chips and Fresh Tomato Salsa
# 1            1         1                          Izze
# 4            2         2                  Chicken Bowl
# 5            3         1                  Chicken Bowl
# 6            3         1                 Side of Chips
# ...        ...       ...                           ...
# 4152      1660        10                 Bottled Water
# 4235      1691         1                  Chicken Bowl
# 4489      1786         4           Chips and Guacamole
# 4509      1793         1                         Chips
# 4510      1793         1                 Barbacoa Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...

# %%
#sorting the values by most to least expensive

sortExp = Np.sort_values(['item_price'], ascending = False)
sortExp.head()
# Out:
#                          item_name  item_price
# 3598  Chips and Fresh Tomato Salsa       44.25
# 3480                 Carnitas Bowl       35.25
# 1254               Chicken Burrito       35.00
# 3602               Chicken Burrito       35.00
# 3601                Veggie Burrito       33.75

# %%
#mostExp = np.where(df2["item_price"] == max(df2["item_price"]))
mostExp = df2.iloc[np.where(df2["item_price"] == max(df2["item_price"]))]
mostExp.quantity
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %%
#Veggie = df2.groupby(by = 'item_name')
#Veggie.iloc[Veggie["item_name"] == "Veggie Burrito"]
#Veggie = Veggie.sum()
#Veggie = Veggie["item_name"] == "Veggie Salad Bowl"

Veggie = df2.iloc[np.where(df2["item_name"] == "Veggie Salad Bowl")]
Veggie["quantity"].sum()
# Out:
# 18

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
df3.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
df3.shape[0]
# Out:
# 193

# %%
df3.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
#which continent drinks more beer?

Cont_beer = df3.groupby('continent')
Cont_beer = Cont_beer.sum()
Cont_beer.sort_values(by='beer_servings', ascending = False).head(1)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# EU                  8720             5965           6400
#
#            total_litres_of_pure_alcohol
# continent
# EU                                387.8

# %%
df3.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
df3['continent'].describe()
# Out:
# count     170
# unique      5
# top        AF
# freq       53
# Name: continent, dtype: object

# %%
df3.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
df4 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv")
df4.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df4.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %%
#converting the int64 to datetime64

df4.Year = pd.to_datetime(df4.Year, format='%Y')

# %%
#set the year column as index of the dataframe

df4.set_index('Year', drop = True)
df4.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df4.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df4.set_index('Year', drop = True).head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
#group the year by decades and sum the values

df4.set_index('Year', drop = True).head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
df4.groupby((df4.index.Year//10)*10).sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-c790a6d5e8a0> in <module>
# ----> 1 df4.groupby((df4.index.Year//10)*10).sum()
#
# AttributeError: 'DatetimeIndex' object has no attribute 'Year'

# %%
df4 = df4.set_index('Year', drop = True).head()

# %%
df4.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
df4.dtypes
# Out:
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %%
# Uses resample to sum each decade
crimes = df4.resample('10AS').sum()

# Uses resample to get the max value only for the "Population" column
population = df4['Population'].resample('10AS').max()

# Updating the "Population" column
crimes['Population'] = population
crimes
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   191141000  19298500  1560550  17737900   44380          91030
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   572230              852910   5155600       10670200
#
#             Vehicle_Theft
# Year
# 1960-01-01        1912100

# %%
df4.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
crimes = df4.resample('10AS').sum()
crimes.head()
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   927710175  19298500  1560550  17737900   44380          91030
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   572230              852910   5155600       10670200
#
#             Vehicle_Theft
# Year
# 1960-01-01        1912100

# %%
MR = df4[["Murder","Robbery"]]

# %%
df4.reset_index(drop = True)
# Out:
#    Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0   179323175  3384200   288460   3095700    9110          17190   107840
# 1   182992000  3488000   289390   3198600    8740          17220   106670
# 2   185771000  3752200   301510   3450700    8530          17550   110860
# 3   188483000  4109500   316970   3792500    8640          17650   116470
# 4   191141000  4564600   364220   4200400    9360          21420   130390
#
#    Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0              154320    912100        1855400         328200
# 1              156760    949600        1913000         336000
# 2              164570    994300        2089600         366800
# 3              174210   1086400        2297800         408300
# 4              203050   1213200        2514400         472800

# %%
df4 = df4.reset_index(drop = True)
df4.head()
# Out:
#    level_0  index       Year  Population    Total  Violent  Property  Murder  \
# 0        0      0 1960-01-01   179323175  3384200   288460   3095700    9110
# 1        1      1 1961-01-01   182992000  3488000   289390   3198600    8740
# 2        2      2 1962-01-01   185771000  3752200   301510   3450700    8530
# 3        3      3 1963-01-01   188483000  4109500   316970   3792500    8640
# 4        4      4 1964-01-01   191141000  4564600   364220   4200400    9360
#
#    Forcible_Rape  Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# 0          17190   107840              154320    912100        1855400
# 1          17220   106670              156760    949600        1913000
# 2          17550   110860              164570    994300        2089600
# 3          17650   116470              174210   1086400        2297800
# 4          21420   130390              203050   1213200        2514400
#
#    Vehicle_Theft
# 0         328200
# 1         336000
# 2         366800
# ...

# %%
df4 = df4.drop('index', axis = 1)
df4.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df4.iloc[[3,4,8]]
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
# 8  1968   199399000  6720200   595010   6125200   13800          31670
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800
# 8   262840              286700   1858900        3482700         783600

# %%
df4.loc[df4.index[[3, 4, 8]], ['Murder', 'Robbery']]
# Out:
#    Murder  Robbery
# 3    8640   116470
# 4    9360   130390
# 8   13800   262840

# %%
df4[df4['Murder']>24000]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 31  1991   252177000  14872900  1911770  12961100   24700         106590
# 33  1993   257908000  14144800  1926020  12218800   24530         106010
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 31   687730             1092740   3157200        8142200        1661700
# 33   659870             1135610   2834800        7820900        1563100

# %%
df4[df4['Murder'].between(20000,24000)]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 14  1974   211392000  10253400   974720   9278700   20710          55400
# 15  1975   213124000  11292400  1039710  10252700   20510          56090
# 19  1979   220099000  12249500  1208030  11041500   21460          76390
# 20  1980   225349264  13408300  1344520  12063700   23040          82990
# 21  1981   229146000  13423800  1361820  12061900   22520          82500
# 22  1982   231534000  12974400  1322390  11652000   21010          78770
# 26  1986   240132887  13211869  1489169  11722700   20613          91459
# 27  1987   242282918  13508700  1483999  12024700   20096          91110
# 28  1988   245807000  13923100  1566220  12356900   20680          92490
# 29  1989   248239000  14251400  1646040  12605400   21500          94500
# 30  1990   248709873  14475600  1820130  12655500   23440         102560
# 32  1992   255082000  14438200  1932270  12505900   23760         109060
# ...

# %%
MurderMean = df4.groupby('Year')
MurderMean = MurderMean.mean()
MurderMean.head()
# Out:
#       Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175  3384200   288460   3095700    9110          17190   107840
# 1961   182992000  3488000   289390   3198600    8740          17220   106670
# 1962   185771000  3752200   301510   3450700    8530          17550   110860
# 1963   188483000  4109500   316970   3792500    8640          17650   116470
# 1964   191141000  4564600   364220   4200400    9360          21420   130390
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960              154320    912100        1855400         328200
# 1961              156760    949600        1913000         336000
# 1962              164570    994300        2089600         366800
# 1963              174210   1086400        2297800         408300
# 1964              203050   1213200        2514400         472800

# %%
df4.groupby('Year')['Murder'].mean().head()
# Out:
# Year
# 1960    9110
# 1961    8740
# 1962    8530
# 1963    8640
# 1964    9360
# Name: Murder, dtype: int64

# %%
df4.sort_values(by =['Murder','Violent'], ascending = [False,True]).head()
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 31  1991   252177000  14872900  1911770  12961100   24700         106590
# 33  1993   257908000  14144800  1926020  12218800   24530         106010
# 32  1992   255082000  14438200  1932270  12505900   23760         109060
# 30  1990   248709873  14475600  1820130  12655500   23440         102560
# 34  1994   260341000  13989500  1857670  12131900   23330         102220
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 31   687730             1092740   3157200        8142200        1661700
# 33   659870             1135610   2834800        7820900        1563100
# 32   672480             1126970   2979900        7915200        1610800
# 30   639270             1054860   3073900        7945700        1635900
# 34   618950             1113180   2712800        7879800        1539300
